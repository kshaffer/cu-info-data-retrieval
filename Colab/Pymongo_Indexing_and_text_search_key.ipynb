# %% [markdown]
# # MongoDB/Pymongo Indexes and Text Search
#
# Work in driver/navigator pairs with a single laptop. Talk through each idea before you code so both partners understand the plan.

# %% [markdown]
# ## 1. Setup
#
# Import the core libraries we will need for HTTP requests, JSON inspection, and quick analyses.

# %%
from pymongo import MongoClient
from pprint import pprint
# Out:
# /Users/kps/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # 2. Retrieve posts from your local MongoDB database

# %%
# create database connection
client = MongoClient()
db = client.mastodon_test
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mastodon_test')

# %%
# show collections in mastodon_test
db.list_collection_names()
# Out:
# ['posts']

# %%
# assign variable to collection in mastodon_test
coll = db.posts
coll
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mastodon_test'), 'posts')

# %%
# confirm number of documents
coll.count_documents({})
# Out:
# 366

# %%
# show a sample post from the collection
sample = coll.find_one()
pprint(sample)
# Out:
# {'_id': ObjectId('68f5436b9bd0346fe634cd0a'),
#  'account': {'acct': 'richpuchalsky@mastodon.social',
#              'avatar': 'https://storage.googleapis.com/hci-social-storage/cache/accounts/avatars/112/010/066/220/976/631/original/f03fbc36a0b683f3.jpg',
#              'avatar_static': 'https://storage.googleapis.com/hci-social-storage/cache/accounts/avatars/112/010/066/220/976/631/original/f03fbc36a0b683f3.jpg',
#              'bot': False,
#              'created_at': '2024-02-24T00:00:00.000Z',
#              'discoverable': True,
#              'display_name': 'Rich Puchalsky  ⩜⃝',
#              'emojis': [],
#              'fields': [{'name': 'blog',
#                          'value': '<a href="https://rpuchalsky.blogspot.com/" '
#                                   'target="_blank" rel="nofollow noopener" '
#                                   'translate="no"><span '
#                                   'class="invisible">https://</span><span '
#                                   'class="">rpuchalsky.blogspot.com/</span><span '
#                                   'class="invisible"></span></a>',
#                          'verified_at': '2025-10-18T01:21:04.906+00:00'},
#                         {'name': 'personal page',
#                          'value': '<a '
#                                   'href="https://grconnect.com/rpuchalsky/index.html" '
#                                   'target="_blank" rel="nofollow noopener" '
#                                   'translate="no"><span '
#                                   'class="invisible">https://</span><span '
#                                   'class="ellipsis">grconnect.com/rpuchalsky/index</span><span '
#                                   'class="invisible">.html</span></a>',
#                          'verified_at': '2025-10-18T01:21:05.078+00:00'}],
#              'followers_count': 963,
#              'following_count': 212,
#              'group': False,
#              'header': 'https://storage.googleapis.com/hci-social-storage/cache/accounts/headers/112/010/066/220/976/631/original/0951dbbb1ba8356b.jpg',
#              'header_static': 'https://storage.googleapis.com/hci-social-storage/cache/accounts/headers/112/010/066/220/976/631/original/0951dbbb1ba8356b.jpg',
#              'hide_collections': False,
#              'id': '112010066220976631',
#              'indexable': True,
#              'last_status_at': '2025-10-19',
#              'locked': False,
#              'note': '<p>freelance librarian, anarchist</p>',
#              'statuses_count': 8313,
#              'uri': 'https://mastodon.social/users/richpuchalsky',
#              'url': 'https://mastodon.social/@richpuchalsky',
#              'username': 'richpuchalsky'},
#  'card': None,
#  'content': '<p>Periodic reminder: anarchists oppose the state.</p><p>But what '
#             "about the welfare state?  No, that's part of the "
#             'state.</p><p>What about your favorite socdem politician?  No, '
#             'they are running for a state office.</p><p>What about reviving '
#             'the honor and dignity of the empire?  What about the majesty of '
#             'the law?  What about a well trained police force?  No.</p><p>What '
#             'about "harm reduction" through voting for the lesser evil, and '
#             'regulatory reform?  No.</p>',
#  'created_at': '2025-10-19T19:57:19.000Z',
#  'edited_at': None,
#  'emojis': [],
#  'favourites_count': 0,
#  'id': '115402594085552801',
#  'in_reply_to_account_id': None,
#  'in_reply_to_id': None,
#  'language': 'en',
#  'media_attachments': [],
#  'mentions': [],
#  'poll': None,
#  'quote': None,
#  'reblog': None,
#  'reblogs_count': 0,
#  'replies_count': 0,
#  'sensitive': False,
#  'spoiler_text': '',
#  'tags': [],
#  'uri': 'https://mastodon.social/users/richpuchalsky/statuses/115402594027509744',
#  'url': 'https://mastodon.social/@richpuchalsky/115402594027509744',
#  'visibility': 'public'}

# %% [markdown]
# # 3. .explain()

# %%
# Start by using explain to see what MongoDB does in a basic .find() query.
exp = coll.find({}).explain()
pprint(exp)
# Out:
# {'command': {'$db': 'mastodon_test', 'filter': {}, 'find': 'posts'},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 366,
#                                         'direction': 'forward',
#                                         'docsExamined': 366,
#                                         'executionTimeMillisEstimate': 0,
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 366,
#                                         'needTime': 0,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'COLLSCAN',
#                                         'works': 367},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 2,
#                     'nReturned': 366,
#                     'totalDocsExamined': 366,
#                     'totalKeysExamined': 0},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 2,
#                   'parsedQuery': {},
#                   'planCacheKey': '7DF350EE',
#                   'planCacheShapeHash': '8F2383EE',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '8F2383EE',
#                   'rejectedPlans': [],
#                   'winningPlan': {'direction': 'forward',
#                                   'isCached': False,
#                                   'stage': 'COLLSCAN'}},
#  'queryShapeHash': 'E8D50A5DED336B4096BAAD690A26232A150A9CD8347369C66066D52B64032AD4',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %% [markdown]
# Copy this output and paste it into ChatGPT, Claude, or Gemini, and ask it to explain what it sees in plain English, noting any indexes it sees and is using.

# %% [markdown]
# Things are funky in Pymongo when we're dealing with aggregation queries, though. _More complicated than in your reading on MongoDB!_ Let's unpack this with a pipeline aggregation query from last week's notebook.

# %%
pipeline = [
    {'$unwind': '$tags'},
    {'$project': {
        '_id': 0,
        'acct': '$account.acct',
        'created_at': 1,
        'hashtag': '$tags.name'
    }},
    {'$group': {
        '_id': '$hashtag',
        'count': {'$sum': 1}
    }},
    {'$sort': {'count': -1}},
    {'$limit': 10}
]

result = coll.aggregate(pipeline)
for doc in result:
    pprint(doc)
# Out:
# {'_id': 'nature', 'count': 8}
# {'_id': 'nokings', 'count': 6}
# {'_id': 'space', 'count': 6}
# {'_id': 'Astronomy', 'count': 6}
# {'_id': 'photography', 'count': 6}
# {'_id': 'astro', 'count': 5}
# {'_id': 'mars', 'count': 5}
# {'_id': 'planets', 'count': 5}
# {'_id': 'spacex', 'count': 5}
# {'_id': 'nasa', 'count': 5}

# %% [markdown]
# If we do what we did above with the .find() query, it won't work.

# %%
exp = coll.aggregate(pipeline).explain()
pprint(exp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 exp = coll.aggregate(pipeline).explain()
#       2 pprint(exp)
#
# AttributeError: 'CommandCursor' object has no attribute 'explain'

# %% [markdown]
# Here's how we have to do it. (Hang onto this code so you can reuse it in the future.)

# %%
plan = coll.database.command(
    "explain",
    {
        "aggregate": coll.name,
        "pipeline": pipeline,
        "cursor": {}
    },
    verbosity="executionStats"  # ✅ accepted here
)

pprint(plan)
# Out:
# {'command': {'$db': 'mastodon_test',
#              'aggregate': 'posts',
#              'cursor': {},
#              'pipeline': [{'$unwind': '$tags'},
#                           {'$project': {'_id': 0,
#                                         'acct': '$account.acct',
#                                         'created_at': 1,
#                                         'hashtag': '$tags.name'}},
#                           {'$group': {'_id': '$hashtag', 'count': {'$sum': 1}}},
#                           {'$sort': {'count': -1}},
#                           {'$limit': 10}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryShapeHash': '547B17851AE3498F6B69795F053BCD77795BFCEF65EEE99D0F40A18E607A0546',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$cursor': {'executionStats': {'executionStages': {'advanced': 366,
#                                                                 'executionTimeMillisEstimate': 0,
#                                                                 'inputStage': {'advanced': 366,
#                                                                                'direction': 'forward',
#                                                                                'docsExamined': 366,
#                                                                                'executionTimeMillisEstimate': 0,
#                                                                                'isEOF': 1,
#                                                                                'nReturned': 366,
#                                                                                'needTime': 0,
#                                                                                'needYield': 0,
#                                                                                'restoreState': 4,
#                                                                                'saveState': 4,
#                                                                                'stage': 'COLLSCAN',
#                                                                                'works': 367},
#                                                                 'isCached': False,
#                                                                 'isEOF': 1,
#                                                                 'nReturned': 366,
#                                                                 'needTime': 0,
#                                                                 'needYield': 0,
#                                                                 'restoreState': 4,
#                                                                 'saveState': 4,
#                                                                 'stage': 'PROJECTION_DEFAULT',
#                                                                 'transformBy': {'_id': 0,
#                                                                                 'account.acct': 1,
#                                                                                 'created_at': 1,
#                                                                                 'tags': 1},
#                                                                 'works': 367},
#                                             'executionSuccess': True,
#                                             'executionTimeMillis': 7,
#                                             'nReturned': 366,
#                                             'totalDocsExamined': 366,
#                                             'totalKeysExamined': 0},
#                          'queryPlanner': {'indexFilterSet': False,
#                                           'maxIndexedAndSolutionsReached': False,
#                                           'maxIndexedOrSolutionsReached': False,
#                                           'maxScansToExplodeReached': False,
#                                           'namespace': 'mastodon_test.posts',
#                                           'optimizationTimeMillis': 0,
#                                           'parsedQuery': {},
#                                           'planCacheKey': '3267225A',
#                                           'planCacheShapeHash': 'BCC56A92',
#                                           'prunedSimilarIndexes': False,
#                                           'queryHash': 'BCC56A92',
#                                           'rejectedPlans': [],
#                                           'winningPlan': {'inputStage': {'direction': 'forward',
#                                                                          'stage': 'COLLSCAN'},
#                                                           'isCached': False,
#                                                           'stage': 'PROJECTION_DEFAULT',
#                                                           'transformBy': {'_id': 0,
#                                                                           'account.acct': 1,
#                                                                           'created_at': 1,
#                                                                           'tags': 1}}}},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 366},
#             {'$unwind': {'path': '$tags'},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 588},
#             {'$project': {'_id': False,
#                           'acct': '$account.acct',
#                           'created_at': True,
#                           'hashtag': '$tags.name'},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 588},
#             {'$group': {'_id': '$hashtag', 'count': {'$sum': {'$const': 1}}},
#              'executionTimeMillisEstimate': 2,
#              'maxAccumulatorMemoryUsageBytes': {'count': 54400},
#              'nReturned': 400,
#              'numBytesSpilledEstimate': 0,
#              'spilledDataStorageSize': 0,
#              'spilledRecords': 0,
#              'spills': 0,
#              'totalOutputDataSizeBytes': 100616,
#              'usedDisk': False},
#             {'$sort': {'limit': 10, 'sortKey': {'count': -1}},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 10,
#              'spilledDataStorageSize': 0,
#              'spills': 0,
#              'totalDataSizeSortedBytesEstimate': 2609,
#              'usedDisk': False}]}

# %% [markdown]
# Now copy that output, paste it into an AI chat, and ask it to explain it in plain English, specifically referencing any indexes it finds.

# %%
# now take ANY .aggregate() query from last week's notebook, run .explain() on it, and ask an AI chat to explain it in plain English.

...

# %% [markdown]
# ## 4. Standard indexes

# %% [markdown]
# Let's practice indexing with the account.acct field for faster account searching.

# %%
# Pick a username from your database

username = coll.find_one()['account']['acct']
print(username)
# Out:
# richpuchalsky@mastodon.social

# %%
# search for all posts from that user and run .explain()
# Use AI (or your own eyes -- look at 'winningPlan', do you see 'COLLSCAN'?) to ensure that it is not using any indexes

posts = coll.find({'account.acct': username})
pprint(posts.explain())
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {'account.acct': 'richpuchalsky@mastodon.social'},
#              'find': 'posts'},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 1,
#                                         'direction': 'forward',
#                                         'docsExamined': 366,
#                                         'executionTimeMillisEstimate': 0,
#                                         'filter': {'account.acct': {'$eq': 'richpuchalsky@mastodon.social'}},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 1,
#                                         'needTime': 365,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'COLLSCAN',
#                                         'works': 367},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 1,
#                     'nReturned': 1,
#                     'totalDocsExamined': 366,
#                     'totalKeysExamined': 0},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {'account.acct': {'$eq': 'richpuchalsky@mastodon.social'}},
#                   'planCacheKey': '986ADF31',
#                   'planCacheShapeHash': '4465F055',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '4465F055',
#                   'rejectedPlans': [],
#                   'winningPlan': {'direction': 'forward',
#                                   'filter': {'account.acct': {'$eq': 'richpuchalsky@mastodon.social'}},
#                                   'isCached': False,
#                                   'stage': 'COLLSCAN'}},
#  'queryShapeHash': 'D47928E33F63912C4C1C4FC5D1AE1412576888211379E826D86400E6852A13AA',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
# now let's index that field

coll.create_index([("account.acct", 1)],
                  name="acct_index") # name optional, but can help debug
# Out:
# 'acct_index'

# %%
# rerun your explain and explore the output to ensure the index is being used
# use AI to help analyze your output if necessary (or just look for 'winningPlan' -- do you see an index? named acct_index?)

posts = coll.find({'account.acct': username})
pprint(posts.explain())
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {'account.acct': 'richpuchalsky@mastodon.social'},
#              'find': 'posts'},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 1,
#                                         'alreadyHasObj': 0,
#                                         'docsExamined': 1,
#                                         'executionTimeMillisEstimate': 0,
#                                         'inputStage': {'advanced': 1,
#                                                        'direction': 'forward',
#                                                        'dupsDropped': 0,
#                                                        'dupsTested': 0,
#                                                        'executionTimeMillisEstimate': 0,
#                                                        'indexBounds': {'account.acct': ['["richpuchalsky@mastodon.social", '
#                                                                                         '"richpuchalsky@mastodon.social"]']},
#                                                        'indexName': 'acct_index',
#                                                        'indexVersion': 2,
#                                                        'isEOF': 1,
#                                                        'isMultiKey': False,
#                                                        'isPartial': False,
#                                                        'isSparse': False,
#                                                        'isUnique': False,
#                                                        'keyPattern': {'account.acct': 1},
#                                                        'keysExamined': 1,
#                                                        'multiKeyPaths': {'account.acct': []},
#                                                        'nReturned': 1,
#                                                        'needTime': 0,
#                                                        'needYield': 0,
#                                                        'restoreState': 0,
#                                                        'saveState': 0,
#                                                        'seeks': 1,
#                                                        'stage': 'IXSCAN',
#                                                        'works': 2},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 1,
#                                         'needTime': 0,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'FETCH',
#                                         'works': 2},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 5,
#                     'nReturned': 1,
#                     'totalDocsExamined': 1,
#                     'totalKeysExamined': 1},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {'account.acct': {'$eq': 'richpuchalsky@mastodon.social'}},
#                   'planCacheKey': '1D55F994',
#                   'planCacheShapeHash': '4465F055',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '4465F055',
#                   'rejectedPlans': [],
#                   'winningPlan': {'inputStage': {'direction': 'forward',
#                                                  'indexBounds': {'account.acct': ['["richpuchalsky@mastodon.social", '
#                                                                                   '"richpuchalsky@mastodon.social"]']},
#                                                  'indexName': 'acct_index',
#                                                  'indexVersion': 2,
#                                                  'isMultiKey': False,
#                                                  'isPartial': False,
#                                                  'isSparse': False,
#                                                  'isUnique': False,
#                                                  'keyPattern': {'account.acct': 1},
#                                                  'multiKeyPaths': {'account.acct': []},
#                                                  'stage': 'IXSCAN'},
#                                   'isCached': False,
#                                   'stage': 'FETCH'}},
#  'queryShapeHash': 'D47928E33F63912C4C1C4FC5D1AE1412576888211379E826D86400E6852A13AA',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %% [markdown]
# Now let's do one on followers_count. Since we'll typically be looking for accounts with the MOST followers, we'll want the index in DESCENDING order.

# %%
# first, run a find query that identifies the 10 posts (not accounts!) with the most followers, and add .explain().
# what method is it using?

exp = coll.find({}).sort('followers_count', -1).limit(10).explain()

pprint(exp)
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {},
#              'find': 'posts',
#              'limit': 10,
#              'singleBatch': True,
#              'sort': {'followers_count': -1}},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 10,
#                                         'executionTimeMillisEstimate': 0,
#                                         'inputStage': {'advanced': 366,
#                                                        'direction': 'forward',
#                                                        'docsExamined': 366,
#                                                        'executionTimeMillisEstimate': 0,
#                                                        'isEOF': 1,
#                                                        'nReturned': 366,
#                                                        'needTime': 0,
#                                                        'needYield': 0,
#                                                        'restoreState': 0,
#                                                        'saveState': 0,
#                                                        'stage': 'COLLSCAN',
#                                                        'works': 367},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'limitAmount': 10,
#                                         'memLimit': 104857600,
#                                         'nReturned': 10,
#                                         'needTime': 367,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'sortPattern': {'followers_count': -1},
#                                         'spilledDataStorageSize': 0,
#                                         'spills': 0,
#                                         'stage': 'SORT',
#                                         'totalDataSizeSorted': 37854,
#                                         'type': 'simple',
#                                         'usedDisk': False,
#                                         'works': 378},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 0,
#                     'nReturned': 10,
#                     'totalDocsExamined': 366,
#                     'totalKeysExamined': 0},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {},
#                   'planCacheKey': '859C0E78',
#                   'planCacheShapeHash': '59882AC8',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '59882AC8',
#                   'rejectedPlans': [],
#                   'winningPlan': {'inputStage': {'direction': 'forward',
#                                                  'stage': 'COLLSCAN'},
#                                   'isCached': False,
#                                   'limitAmount': 10,
#                                   'memLimit': 104857600,
#                                   'sortPattern': {'followers_count': -1},
#                                   'stage': 'SORT',
#                                   'type': 'simple'}},
#  'queryShapeHash': '342B55E029F15EE25CB6689B3BE8D22AA38B0CAF74A81CA21F7D5C4968679755',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
# now add a DESCENDING index on that field

coll.create_index([("followers_count", -1)],
                  name="followers_desc_index")
# Out:
# 'followers_desc_index'

# %%
# rerun the explain to ensure the index is being used

exp = coll.find({}).sort('followers_count', -1).limit(10).explain()

pprint(exp)
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {},
#              'find': 'posts',
#              'limit': 10,
#              'singleBatch': True,
#              'sort': {'followers_count': -1}},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 10,
#                                         'executionTimeMillisEstimate': 0,
#                                         'inputStage': {'advanced': 10,
#                                                        'alreadyHasObj': 0,
#                                                        'docsExamined': 10,
#                                                        'executionTimeMillisEstimate': 0,
#                                                        'inputStage': {'advanced': 10,
#                                                                       'direction': 'forward',
#                                                                       'dupsDropped': 0,
#                                                                       'dupsTested': 0,
#                                                                       'executionTimeMillisEstimate': 0,
#                                                                       'indexBounds': {'followers_count': ['[MaxKey, '
#                                                                                                           'MinKey]']},
#                                                                       'indexName': 'followers_desc_index',
#                                                                       'indexVersion': 2,
#                                                                       'isEOF': 0,
#                                                                       'isMultiKey': False,
#                                                                       'isPartial': False,
#                                                                       'isSparse': False,
#                                                                       'isUnique': False,
#                                                                       'keyPattern': {'followers_count': -1},
#                                                                       'keysExamined': 10,
#                                                                       'multiKeyPaths': {'followers_count': []},
#                                                                       'nReturned': 10,
#                                                                       'needTime': 0,
#                                                                       'needYield': 0,
#                                                                       'restoreState': 0,
#                                                                       'saveState': 0,
#                                                                       'seeks': 1,
#                                                                       'stage': 'IXSCAN',
#                                                                       'works': 10},
#                                                        'isEOF': 0,
#                                                        'nReturned': 10,
#                                                        'needTime': 0,
#                                                        'needYield': 0,
#                                                        'restoreState': 0,
#                                                        'saveState': 0,
#                                                        'stage': 'FETCH',
#                                                        'works': 10},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'limitAmount': 10,
#                                         'nReturned': 10,
#                                         'needTime': 0,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'LIMIT',
#                                         'works': 11},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 2,
#                     'nReturned': 10,
#                     'totalDocsExamined': 10,
#                     'totalKeysExamined': 10},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {},
#                   'planCacheKey': '859C0E78',
#                   'planCacheShapeHash': '59882AC8',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '59882AC8',
#                   'rejectedPlans': [],
#                   'winningPlan': {'inputStage': {'inputStage': {'direction': 'forward',
#                                                                 'indexBounds': {'followers_count': ['[MaxKey, '
#                                                                                                     'MinKey]']},
#                                                                 'indexName': 'followers_desc_index',
#                                                                 'indexVersion': 2,
#                                                                 'isMultiKey': False,
#                                                                 'isPartial': False,
#                                                                 'isSparse': False,
#                                                                 'isUnique': False,
#                                                                 'keyPattern': {'followers_count': -1},
#                                                                 'multiKeyPaths': {'followers_count': []},
#                                                                 'stage': 'IXSCAN'},
#                                                  'stage': 'FETCH'},
#                                   'isCached': False,
#                                   'limitAmount': 10,
#                                   'stage': 'LIMIT'}},
#  'queryShapeHash': '342B55E029F15EE25CB6689B3BE8D22AA38B0CAF74A81CA21F7D5C4968679755',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %% [markdown]
# ## 5. Array indexes

# %% [markdown]
# To index every element in an array (like tags or media_attachments), just create an index on that field. MongoDB will automatically index each element in the arrays. Note, though, that these indexes will be more "expensive" (take up more space, add more time when adding new documents) than one that indexes one element per document (like account.acct or content).

# %%
# grab the grouping query from last week's notebook that returns the top 10 hashtags (there were two, either one is fine). Run just that query.

pipeline = [
    {'$unwind': '$tags'},
    {'$group': {
        '_id': '$tags.name',
        'count': {'$sum': 1}
    }},
    {'$sort': {'count': -1}},
    {'$limit': 10}
]

result = coll.aggregate(pipeline)
for doc in result:
    pprint(doc)
# Out:
# {'_id': 'nature', 'count': 8}
# {'_id': 'space', 'count': 6}
# {'_id': 'photography', 'count': 6}
# {'_id': 'nokings', 'count': 6}
# {'_id': 'Astronomy', 'count': 6}
# {'_id': 'astrology', 'count': 5}
# {'_id': 'spaceexploration', 'count': 5}
# {'_id': 'solarsystem', 'count': 5}
# {'_id': 'esa', 'count': 5}
# {'_id': 'spacex', 'count': 5}

# %%
# now run explain() on this query (remember that aggregate requires a more involved method, but you can just copy and paste from above).
# This output will be more complicated, so you may want to use AI to help explain it to you and check for index usage.

plan = coll.database.command(
    "explain",
    {
        "aggregate": coll.name,
        "pipeline": pipeline,
        "cursor": {}
    },
    verbosity="executionStats"  # ✅ accepted here
)

pprint(plan)
# Out:
# {'command': {'$db': 'mastodon_test',
#              'aggregate': 'posts',
#              'cursor': {},
#              'pipeline': [{'$unwind': '$tags'},
#                           {'$group': {'_id': '$tags.name',
#                                       'count': {'$sum': 1}}},
#                           {'$sort': {'count': -1}},
#                           {'$limit': 10}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryShapeHash': 'BC0B12B3189A69E070017BC31B17B9BD7BAD26AFB03B4527FDDCE5E300DEF7B5',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$cursor': {'executionStats': {'executionStages': {'advanced': 366,
#                                                                 'executionTimeMillisEstimate': 0,
#                                                                 'inputStage': {'advanced': 366,
#                                                                                'direction': 'forward',
#                                                                                'docsExamined': 366,
#                                                                                'executionTimeMillisEstimate': 0,
#                                                                                'isEOF': 1,
#                                                                                'nReturned': 366,
#                                                                                'needTime': 0,
#                                                                                'needYield': 0,
#                                                                                'restoreState': 4,
#                                                                                'saveState': 4,
#                                                                                'stage': 'COLLSCAN',
#                                                                                'works': 367},
#                                                                 'isCached': False,
#                                                                 'isEOF': 1,
#                                                                 'nReturned': 366,
#                                                                 'needTime': 0,
#                                                                 'needYield': 0,
#                                                                 'restoreState': 4,
#                                                                 'saveState': 4,
#                                                                 'stage': 'PROJECTION_SIMPLE',
#                                                                 'transformBy': {'_id': 0,
#                                                                                 'tags': 1},
#                                                                 'works': 367},
#                                             'executionSuccess': True,
#                                             'executionTimeMillis': 2,
#                                             'nReturned': 366,
#                                             'totalDocsExamined': 366,
#                                             'totalKeysExamined': 0},
#                          'queryPlanner': {'indexFilterSet': False,
#                                           'maxIndexedAndSolutionsReached': False,
#                                           'maxIndexedOrSolutionsReached': False,
#                                           'maxScansToExplodeReached': False,
#                                           'namespace': 'mastodon_test.posts',
#                                           'optimizationTimeMillis': 0,
#                                           'parsedQuery': {},
#                                           'planCacheKey': 'ABDDDEAF',
#                                           'planCacheShapeHash': '46410253',
#                                           'prunedSimilarIndexes': False,
#                                           'queryHash': '46410253',
#                                           'rejectedPlans': [],
#                                           'winningPlan': {'inputStage': {'direction': 'forward',
#                                                                          'stage': 'COLLSCAN'},
#                                                           'isCached': False,
#                                                           'stage': 'PROJECTION_SIMPLE',
#                                                           'transformBy': {'_id': 0,
#                                                                           'tags': 1}}}},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 366},
#             {'$unwind': {'path': '$tags'},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 588},
#             {'$group': {'_id': '$tags.name', 'count': {'$sum': {'$const': 1}}},
#              'executionTimeMillisEstimate': 2,
#              'maxAccumulatorMemoryUsageBytes': {'count': 54400},
#              'nReturned': 400,
#              'numBytesSpilledEstimate': 0,
#              'spilledDataStorageSize': 0,
#              'spilledRecords': 0,
#              'spills': 0,
#              'totalOutputDataSizeBytes': 100616,
#              'usedDisk': False},
#             {'$sort': {'limit': 10, 'sortKey': {'count': -1}},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 10,
#              'spilledDataStorageSize': 0,
#              'spills': 0,
#              'totalDataSizeSortedBytesEstimate': 2530,
#              'usedDisk': False}]}

# %%
# now add an index to the hashtag name field, ascending is fine.

coll.create_index(
    [("tags.name", 1)],
    name="tags_name_index"
)
# Out:
# 'tags_name_index'

# %%
# now rerun the above explain to ensure the index is being used.

plan = coll.database.command(
    "explain",
    {
        "aggregate": coll.name,
        "pipeline": pipeline,
        "cursor": {}
    },
    verbosity="executionStats"  # ✅ accepted here
)

pprint(plan)
# Out:
# {'command': {'$db': 'mastodon_test',
#              'aggregate': 'posts',
#              'cursor': {},
#              'pipeline': [{'$unwind': '$tags'},
#                           {'$group': {'_id': '$tags.name',
#                                       'count': {'$sum': 1}}},
#                           {'$sort': {'count': -1}},
#                           {'$limit': 10}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryShapeHash': 'BC0B12B3189A69E070017BC31B17B9BD7BAD26AFB03B4527FDDCE5E300DEF7B5',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$cursor': {'executionStats': {'executionStages': {'advanced': 366,
#                                                                 'executionTimeMillisEstimate': 0,
#                                                                 'inputStage': {'advanced': 366,
#                                                                                'direction': 'forward',
#                                                                                'docsExamined': 366,
#                                                                                'executionTimeMillisEstimate': 0,
#                                                                                'isEOF': 1,
#                                                                                'nReturned': 366,
#                                                                                'needTime': 0,
#                                                                                'needYield': 0,
#                                                                                'restoreState': 4,
#                                                                                'saveState': 4,
#                                                                                'stage': 'COLLSCAN',
#                                                                                'works': 367},
#                                                                 'isCached': False,
#                                                                 'isEOF': 1,
#                                                                 'nReturned': 366,
#                                                                 'needTime': 0,
#                                                                 'needYield': 0,
#                                                                 'restoreState': 4,
#                                                                 'saveState': 4,
#                                                                 'stage': 'PROJECTION_SIMPLE',
#                                                                 'transformBy': {'_id': 0,
#                                                                                 'tags': 1},
#                                                                 'works': 367},
#                                             'executionSuccess': True,
#                                             'executionTimeMillis': 3,
#                                             'nReturned': 366,
#                                             'totalDocsExamined': 366,
#                                             'totalKeysExamined': 0},
#                          'queryPlanner': {'indexFilterSet': False,
#                                           'maxIndexedAndSolutionsReached': False,
#                                           'maxIndexedOrSolutionsReached': False,
#                                           'maxScansToExplodeReached': False,
#                                           'namespace': 'mastodon_test.posts',
#                                           'optimizationTimeMillis': 0,
#                                           'parsedQuery': {},
#                                           'planCacheKey': 'ABDDDEAF',
#                                           'planCacheShapeHash': '46410253',
#                                           'prunedSimilarIndexes': False,
#                                           'queryHash': '46410253',
#                                           'rejectedPlans': [],
#                                           'winningPlan': {'inputStage': {'direction': 'forward',
#                                                                          'stage': 'COLLSCAN'},
#                                                           'isCached': False,
#                                                           'stage': 'PROJECTION_SIMPLE',
#                                                           'transformBy': {'_id': 0,
#                                                                           'tags': 1}}}},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 366},
#             {'$unwind': {'path': '$tags'},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 588},
#             {'$group': {'_id': '$tags.name', 'count': {'$sum': {'$const': 1}}},
#              'executionTimeMillisEstimate': 2,
#              'maxAccumulatorMemoryUsageBytes': {'count': 54400},
#              'nReturned': 400,
#              'numBytesSpilledEstimate': 0,
#              'spilledDataStorageSize': 0,
#              'spilledRecords': 0,
#              'spills': 0,
#              'totalOutputDataSizeBytes': 100616,
#              'usedDisk': False},
#             {'$sort': {'limit': 10, 'sortKey': {'count': -1}},
#              'executionTimeMillisEstimate': 2,
#              'nReturned': 10,
#              'spilledDataStorageSize': 0,
#              'spills': 0,
#              'totalDataSizeSortedBytesEstimate': 2530,
#              'usedDisk': False}]}

# %%
coll.find({'tags.name': 'nature'}).explain()
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'mastodon_test.posts',
#   'parsedQuery': {'tags.name': {'$eq': 'nature'}},
#   'indexFilterSet': False,
#   'queryHash': '8818BAD0',
#   'planCacheShapeHash': '8818BAD0',
#   'planCacheKey': 'C77E1090',
#   'optimizationTimeMillis': 3,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'tags.name': 1},
#     'indexName': 'tags_name_index',
#     'isMultiKey': True,
#     'multiKeyPaths': {'tags.name': ['tags']},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'tags.name': ['["nature", "nature"]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 8,
#   'executionTimeMillis': 6,
#   'totalKeysExamined': 8,
#   'totalDocsExamined': 8,
#   'executionStages': {'isCached': False,
#    'stage': 'FETCH',
#    'nReturned': 8,
#    'executionTimeMillisEstimate': 0,
#    'works': 9,
#    'advanced': 8,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'docsExamined': 8,
#    'alreadyHasObj': 0,
#    'inputStage': {'stage': 'IXSCAN',
#     'nReturned': 8,
#     'executionTimeMillisEstimate': 0,
#     'works': 9,
#     'advanced': 8,
#     'needTime': 0,
#     'needYield': 0,
#     'saveState': 0,
#     'restoreState': 0,
#     'isEOF': 1,
#     'keyPattern': {'tags.name': 1},
#     'indexName': 'tags_name_index',
#     'isMultiKey': True,
#     'multiKeyPaths': {'tags.name': ['tags']},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'tags.name': ['["nature", "nature"]']},
#     'keysExamined': 8,
#     'seeks': 1,
#     'dupsTested': 8,
#     'dupsDropped': 0}},
#   'allPlansExecution': []},
#  'queryShapeHash': 'E131306BD8CD535466EF4D82B0DE5AE0328D0DE82FADE10338E1E888314AA9E9',
#  'command': {'find': 'posts',
#   'filter': {'tags.name': 'nature'},
#   '$db': 'mastodon_test'},
#  'serverInfo': {'host': 'Kriss-MacBook-Pro.local',
#   'port': 27017,
#   'version': '8.0.8',
#   'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'ok': 1.0}

# %% [markdown]
# ## 6. Text indexes and searches

# %% [markdown]
# To perform a keyword or partial text search (like SQL's `WHERE content like '%keyword%'`), we need to use `$regex`.

# %%
# perform a search for the word 'nature' somewhere in the post content

cursor = coll.find({'content': { '$regex': 'nature'}})

for post in cursor:
    pprint(post['content'])
# Out:
# ('<p>Large fallen tree covered in moss and lichen in <a '
#  'href="https://mstdn.ca/tags/Algonquin" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Algonquin</span></a> Park. <a '
#  'href="https://mstdn.ca/tags/Ontario" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Ontario</span></a> <a '
#  'href="https://mstdn.ca/tags/Canada" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Canada</span></a> </p><p><a '
#  'href="https://mstdn.ca/tags/nature" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mstdn.ca/tags/NaturePhotography" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>NaturePhotography</span></a></p>')
# ('<p>Large fallen tree covered in moss and lichen in <a '
#  'href="https://mstdn.ca/tags/Algonquin" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Algonquin</span></a> Park. <a '
#  'href="https://mstdn.ca/tags/Ontario" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Ontario</span></a> <a '
#  'href="https://mstdn.ca/tags/Canada" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Canada</span></a> </p><p><a '
#  'href="https://mstdn.ca/tags/nature" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mstdn.ca/tags/NaturePhotography" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>NaturePhotography</span></a></p>')
# ('<p>How is this not fraud on the part of the broker. How does the word '
#  '"fraud" not even appear once in this article?</p><p><a '
#  'href="https://www.abc.net.au/news/2025-10-20/reused-signature-among-string-of-failures-on-home-build/105792444" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">abc.net.au/news/2025-10-20/reu</span><span '
#  'class="invisible">sed-signature-among-string-of-failures-on-home-build/105792444</span></a></p>')
# ('<p>How is this not fraud on the part of the broker. How does the word '
#  '"fraud" not even appear once in this article?</p><p><a '
#  'href="https://www.abc.net.au/news/2025-10-20/reused-signature-among-string-of-failures-on-home-build/105792444" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">abc.net.au/news/2025-10-20/reu</span><span '
#  'class="invisible">sed-signature-among-string-of-failures-on-home-build/105792444</span></a></p>')
# ('<p>US PhD admissions shrink as fears over Trump’s cuts take hold<br><a '
#  'href="https://www.nature.com/articles/d41586-025-03417-6?utm_source=flipboard&amp;utm_medium=activitypub" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">nature.com/articles/d41586-025</span><span '
#  'class="invisible">-03417-6?utm_source=flipboard&amp;utm_medium=activitypub '
#  '</span></a></p><p>Posted into Latest science news <span class="h-card" '
#  'translate="no"><a '
#  'href="https://flipboard.com/@naturenewsteam/latest-science-news-d3hg9j0hz" '
#  'class="u-url mention" rel="nofollow noopener" '
#  'target="_blank">@<span>latest-science-news-NatureNewsteam</span></a></span></p>')
# ('<p>The Top 3 Weirdest Asteroids We’ve Ever Visited</p><p>Read More: <a '
#  'href="https://astronex.net/the-top-3-weirdest-asteroids-weve-ever-visited/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/the-top-3-weirdes</span><span '
#  'class="invisible">t-asteroids-weve-ever-visited/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>The Mysterious Asteroid Ryugu Mineral That Challenges Planet '
#  'History</p><p>Read More: <a '
#  'href="https://astronex.net/the-mysterious-asteroid-ryugu-mineral-that-challenges-planet-history/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/the-mysterious-as</span><span '
#  'class="invisible">teroid-ryugu-mineral-that-challenges-planet-history/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>TOI-715b: Why Is NASA Calling It Super-Earth?</p><p>Read More: <a '
#  'href="https://astronex.net/toi-715b-why-is-nasa-calling-it-super-earth/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/toi-715b-why-is-n</span><span '
#  'class="invisible">asa-calling-it-super-earth/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>Why Are Scientists Tracking Titan’s Shadows in 2025?</p><p>Read More: <a '
#  'href="https://astronex.net/why-are-scientists-tracking-titans-shadows-in-2025/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/why-are-scientist</span><span '
#  'class="invisible">s-tracking-titans-shadows-in-2025/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>What Did Scientists Find on Mars’s Ancient Riverbeds?</p><p>Read More: <a '
#  'href="https://astronex.net/what-did-scientists-find-on-marss-ancient-riverbeds/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/what-did-scientis</span><span '
#  'class="invisible">ts-find-on-marss-ancient-riverbeds/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>Reports on the homosexual behaviour of penguins in Antarctica were hidden '
#  'for over 100 years </p><p>“Animal Pride, a doc film from CBC’s The Nature of '
#  'Things, brings these findings into the spotlight. </p><p>"We\'ve all heard '
#  'the rhetoric that being queer isn\'t natural," says naturalist Connel '
#  'Bradwell in the film. "This is nature\'s coming-out story."</p><p><a '
#  'href="https://www.cbc.ca/documentaries/the-nature-of-things/reports-on-the-homosexual-behaviour-of-penguins-in-antarctica-were-hidden-for-over-100-years-1.7541056" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">cbc.ca/documentaries/the-natur</span><span '
#  'class="invisible">e-of-things/reports-on-the-homosexual-behaviour-of-penguins-in-antarctica-were-hidden-for-over-100-years-1.7541056</span></a></p>')

# %%
# add `$options: 'i'` to make it case-insensitive

cursor = coll.find({'content': { '$regex': 'nature',
                                 '$options': 'i'}})

for post in cursor:
    pprint(post['content'])
# Out:
# ('<p>Large fallen tree covered in moss and lichen in <a '
#  'href="https://mstdn.ca/tags/Algonquin" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Algonquin</span></a> Park. <a '
#  'href="https://mstdn.ca/tags/Ontario" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Ontario</span></a> <a '
#  'href="https://mstdn.ca/tags/Canada" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Canada</span></a> </p><p><a '
#  'href="https://mstdn.ca/tags/nature" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mstdn.ca/tags/NaturePhotography" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>NaturePhotography</span></a></p>')
# ('<p>Large fallen tree covered in moss and lichen in <a '
#  'href="https://mstdn.ca/tags/Algonquin" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Algonquin</span></a> Park. <a '
#  'href="https://mstdn.ca/tags/Ontario" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Ontario</span></a> <a '
#  'href="https://mstdn.ca/tags/Canada" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>Canada</span></a> </p><p><a '
#  'href="https://mstdn.ca/tags/nature" class="mention hashtag" rel="nofollow '
#  'noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mstdn.ca/tags/NaturePhotography" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>NaturePhotography</span></a></p>')
# ('<p>How is this not fraud on the part of the broker. How does the word '
#  '"fraud" not even appear once in this article?</p><p><a '
#  'href="https://www.abc.net.au/news/2025-10-20/reused-signature-among-string-of-failures-on-home-build/105792444" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">abc.net.au/news/2025-10-20/reu</span><span '
#  'class="invisible">sed-signature-among-string-of-failures-on-home-build/105792444</span></a></p>')
# ('<p>How is this not fraud on the part of the broker. How does the word '
#  '"fraud" not even appear once in this article?</p><p><a '
#  'href="https://www.abc.net.au/news/2025-10-20/reused-signature-among-string-of-failures-on-home-build/105792444" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">abc.net.au/news/2025-10-20/reu</span><span '
#  'class="invisible">sed-signature-among-string-of-failures-on-home-build/105792444</span></a></p>')
# ('<p>The prehistoric Amazon <a '
#  'href="https://www.youtube.com/watch?v=Ns6_igsNsfI" rel="nofollow noopener" '
#  'translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="">youtube.com/watch?v=Ns6_igsNsfI</span><span '
#  'class="invisible"></span></a> </p><p><a '
#  'href="https://thecanadian.social/tags/paleontology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>paleontology</span></a> <a '
#  'href="https://thecanadian.social/tags/wildlife" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>wildlife</span></a> <a '
#  'href="https://thecanadian.social/tags/Nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>Nature</span></a> <a '
#  'href="https://thecanadian.social/tags/ecology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>ecology</span></a> <a '
#  'href="https://thecanadian.social/tags/biodiversity" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>biodiversity</span></a> <a '
#  'href="https://thecanadian.social/tags/environment" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>environment</span></a></p>')
# ('<p>US PhD admissions shrink as fears over Trump’s cuts take hold<br><a '
#  'href="https://www.nature.com/articles/d41586-025-03417-6?utm_source=flipboard&amp;utm_medium=activitypub" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">nature.com/articles/d41586-025</span><span '
#  'class="invisible">-03417-6?utm_source=flipboard&amp;utm_medium=activitypub '
#  '</span></a></p><p>Posted into Latest science news <span class="h-card" '
#  'translate="no"><a '
#  'href="https://flipboard.com/@naturenewsteam/latest-science-news-d3hg9j0hz" '
#  'class="u-url mention" rel="nofollow noopener" '
#  'target="_blank">@<span>latest-science-news-NatureNewsteam</span></a></span></p>')
# ('<p>The Top 3 Weirdest Asteroids We’ve Ever Visited</p><p>Read More: <a '
#  'href="https://astronex.net/the-top-3-weirdest-asteroids-weve-ever-visited/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/the-top-3-weirdes</span><span '
#  'class="invisible">t-asteroids-weve-ever-visited/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>The Mysterious Asteroid Ryugu Mineral That Challenges Planet '
#  'History</p><p>Read More: <a '
#  'href="https://astronex.net/the-mysterious-asteroid-ryugu-mineral-that-challenges-planet-history/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/the-mysterious-as</span><span '
#  'class="invisible">teroid-ryugu-mineral-that-challenges-planet-history/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>TOI-715b: Why Is NASA Calling It Super-Earth?</p><p>Read More: <a '
#  'href="https://astronex.net/toi-715b-why-is-nasa-calling-it-super-earth/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/toi-715b-why-is-n</span><span '
#  'class="invisible">asa-calling-it-super-earth/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>Why Are Scientists Tracking Titan’s Shadows in 2025?</p><p>Read More: <a '
#  'href="https://astronex.net/why-are-scientists-tracking-titans-shadows-in-2025/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/why-are-scientist</span><span '
#  'class="invisible">s-tracking-titans-shadows-in-2025/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>What Did Scientists Find on Mars’s Ancient Riverbeds?</p><p>Read More: <a '
#  'href="https://astronex.net/what-did-scientists-find-on-marss-ancient-riverbeds/" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://</span><span '
#  'class="ellipsis">astronex.net/what-did-scientis</span><span '
#  'class="invisible">ts-find-on-marss-ancient-riverbeds/</span></a></p><p><a '
#  'href="https://mastodon.social/tags/space" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>space</span></a> <a '
#  'href="https://mastodon.social/tags/astrology" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astrology</span></a> <a '
#  'href="https://mastodon.social/tags/astronomy" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astronomy</span></a> <a '
#  'href="https://mastodon.social/tags/NASA" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>NASA</span></a> <a '
#  'href="https://mastodon.social/tags/science" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>science</span></a> <a '
#  'href="https://mastodon.social/tags/solarsystem" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>solarsystem</span></a> <a '
#  'href="https://mastodon.social/tags/astro" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>astro</span></a> <a '
#  'href="https://mastodon.social/tags/nature" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>nature</span></a> <a '
#  'href="https://mastodon.social/tags/mars" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>mars</span></a> <a '
#  'href="https://mastodon.social/tags/esa" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>esa</span></a> <a '
#  'href="https://mastodon.social/tags/spacex" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>spacex</span></a> <a '
#  'href="https://mastodon.social/tags/planets" class="mention hashtag" '
#  'rel="nofollow noopener" target="_blank">#<span>planets</span></a> <a '
#  'href="https://mastodon.social/tags/spaceexploration" class="mention hashtag" '
#  'rel="nofollow noopener" '
#  'target="_blank">#<span>spaceexploration</span></a></p>')
# ('<p>Reports on the homosexual behaviour of penguins in Antarctica were hidden '
#  'for over 100 years </p><p>“Animal Pride, a doc film from CBC’s The Nature of '
#  'Things, brings these findings into the spotlight. </p><p>"We\'ve all heard '
#  'the rhetoric that being queer isn\'t natural," says naturalist Connel '
#  'Bradwell in the film. "This is nature\'s coming-out story."</p><p><a '
#  'href="https://www.cbc.ca/documentaries/the-nature-of-things/reports-on-the-homosexual-behaviour-of-penguins-in-antarctica-were-hidden-for-over-100-years-1.7541056" '
#  'rel="nofollow noopener" translate="no" target="_blank"><span '
#  'class="invisible">https://www.</span><span '
#  'class="ellipsis">cbc.ca/documentaries/the-natur</span><span '
#  'class="invisible">e-of-things/reports-on-the-homosexual-behaviour-of-penguins-in-antarctica-were-hidden-for-over-100-years-1.7541056</span></a></p>')

# %% [markdown]
# For the most robust text searches in MongoDB, we'd have to use their Atlas platform. Most significant is that Atlas is required to do partial-word matches with wildcards. However, as long as we're doing full-word searches, we can run that locally, and we can create a text index to support it.

# %%
# first, run the above search with .explain() to see it without an index

exp = coll.find({'content': { '$regex': 'nature',
                              '$options': 'i'}})

pprint(exp.explain())
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {'content': {'$options': 'i', '$regex': 'nature'}},
#              'find': 'posts'},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 12,
#                                         'direction': 'forward',
#                                         'docsExamined': 366,
#                                         'executionTimeMillisEstimate': 0,
#                                         'filter': {'content': {'$options': 'i',
#                                                                '$regex': 'nature'}},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 12,
#                                         'needTime': 354,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'COLLSCAN',
#                                         'works': 367},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 8,
#                     'nReturned': 12,
#                     'totalDocsExamined': 366,
#                     'totalKeysExamined': 0},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {'content': {'$options': 'i',
#                                               '$regex': 'nature'}},
#                   'planCacheKey': '84AC199C',
#                   'planCacheShapeHash': '64C36454',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '64C36454',
#                   'rejectedPlans': [],
#                   'winningPlan': {'direction': 'forward',
#                                   'filter': {'content': {'$options': 'i',
#                                                          '$regex': 'nature'}},
#                                   'isCached': False,
#                                   'stage': 'COLLSCAN'}},
#  'queryShapeHash': 'ADC8B91C4EAA53E363539ACBA0912D54C267AA533FDB74A6C93CB34121098CC3',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
# now create a TEXT index on content
# note the import statement -- you only need to do that once
# Also note the default_language and language_override fields. This is because Mastodon includes a language field, but it's not always populated, so MongoDB gets confused trying to decide what language(s) to use to support some of their advanced language parsing features. Just use this code if you want to avoid that problem with this data.

from pymongo import TEXT
coll.create_index([("content", TEXT)],
                  name="content_text_index",
                  default_language="english",
                  language_override="__no_override__"
                  )
# Out:
# 'content_text_index'

# %%
# now rerun the above keyword search to ensure the index is being used

exp = coll.find({'content': { '$regex': 'nature'}})

pprint(exp.explain())
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {'content': {'$regex': 'nature'}},
#              'find': 'posts'},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 11,
#                                         'direction': 'forward',
#                                         'docsExamined': 366,
#                                         'executionTimeMillisEstimate': 0,
#                                         'filter': {'content': {'$regex': 'nature'}},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 11,
#                                         'needTime': 355,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'COLLSCAN',
#                                         'works': 367},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 5,
#                     'nReturned': 11,
#                     'totalDocsExamined': 366,
#                     'totalKeysExamined': 0},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {'content': {'$regex': 'nature'}},
#                   'planCacheKey': 'BB6B8E7D',
#                   'planCacheShapeHash': '5FC12979',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '5FC12979',
#                   'rejectedPlans': [],
#                   'winningPlan': {'direction': 'forward',
#                                   'filter': {'content': {'$regex': 'nature'}},
#                                   'isCached': False,
#                                   'stage': 'COLLSCAN'}},
#  'queryShapeHash': 'D3491D161477D36F086F2065AD513812005E9F773192E8D2C9CFFE62A9A9291A',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
# $regex doesn't work with the TEXT index we created. We have to do the text search a little differently. (This method ONLY works with a TEXT index.)
# Again, just copy and paste this code, modifying as necessary, for future projects, including the midterm.

cursor = coll.find(
    {"$text": {"$search": "nature"}},
    {"content": 1}
)

pprint(cursor.explain())
# Out:
# {'command': {'$db': 'mastodon_test',
#              'filter': {'$text': {'$search': 'nature'}},
#              'find': 'posts',
#              'projection': {'content': 1}},
#  'executionStats': {'allPlansExecution': [],
#                     'executionStages': {'advanced': 12,
#                                         'executionTimeMillisEstimate': 0,
#                                         'inputStage': {'advanced': 12,
#                                                        'docsRejected': 0,
#                                                        'executionTimeMillisEstimate': 0,
#                                                        'indexName': 'content_text_index',
#                                                        'indexPrefix': {},
#                                                        'inputStage': {'advanced': 12,
#                                                                       'alreadyHasObj': 0,
#                                                                       'docsExamined': 12,
#                                                                       'executionTimeMillisEstimate': 0,
#                                                                       'inputStage': {'advanced': 12,
#                                                                                      'direction': 'backward',
#                                                                                      'dupsDropped': 0,
#                                                                                      'dupsTested': 12,
#                                                                                      'executionTimeMillisEstimate': 0,
#                                                                                      'indexBounds': {},
#                                                                                      'indexName': 'content_text_index',
#                                                                                      'indexVersion': 2,
#                                                                                      'isEOF': 1,
#                                                                                      'isMultiKey': True,
#                                                                                      'isPartial': False,
#                                                                                      'isSparse': False,
#                                                                                      'isUnique': False,
#                                                                                      'keyPattern': {'_fts': 'text',
#                                                                                                     '_ftsx': 1},
#                                                                                      'keysExamined': 12,
#                                                                                      'nReturned': 12,
#                                                                                      'needTime': 0,
#                                                                                      'needYield': 0,
#                                                                                      'restoreState': 0,
#                                                                                      'saveState': 0,
#                                                                                      'seeks': 1,
#                                                                                      'stage': 'IXSCAN',
#                                                                                      'works': 13},
#                                                                       'isEOF': 1,
#                                                                       'nReturned': 12,
#                                                                       'needTime': 0,
#                                                                       'needYield': 0,
#                                                                       'restoreState': 0,
#                                                                       'saveState': 0,
#                                                                       'stage': 'FETCH',
#                                                                       'works': 13},
#                                                        'isEOF': 1,
#                                                        'nReturned': 12,
#                                                        'needTime': 0,
#                                                        'needYield': 0,
#                                                        'parsedTextQuery': {'negatedPhrases': [],
#                                                                            'negatedTerms': [],
#                                                                            'phrases': [],
#                                                                            'terms': ['natur']},
#                                                        'restoreState': 0,
#                                                        'saveState': 0,
#                                                        'stage': 'TEXT_MATCH',
#                                                        'textIndexVersion': 3,
#                                                        'works': 13},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 12,
#                                         'needTime': 0,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'PROJECTION_SIMPLE',
#                                         'transformBy': {'content': 1},
#                                         'works': 13},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 1,
#                     'nReturned': 12,
#                     'totalDocsExamined': 12,
#                     'totalKeysExamined': 12},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'parsedQuery': {'$text': {'$caseSensitive': False,
#                                             '$diacriticSensitive': False,
#                                             '$language': 'english',
#                                             '$search': 'nature'}},
#                   'planCacheKey': '2BDAE864',
#                   'planCacheShapeHash': '4732DAA9',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '4732DAA9',
#                   'rejectedPlans': [],
#                   'winningPlan': {'inputStage': {'indexName': 'content_text_index',
#                                                  'indexPrefix': {},
#                                                  'inputStage': {'inputStage': {'direction': 'backward',
#                                                                                'indexBounds': {},
#                                                                                'indexName': 'content_text_index',
#                                                                                'indexVersion': 2,
#                                                                                'isMultiKey': True,
#                                                                                'isPartial': False,
#                                                                                'isSparse': False,
#                                                                                'isUnique': False,
#                                                                                'keyPattern': {'_fts': 'text',
#                                                                                               '_ftsx': 1},
#                                                                                'stage': 'IXSCAN'},
#                                                                 'stage': 'FETCH'},
#                                                  'parsedTextQuery': {'negatedPhrases': [],
#                                                                      'negatedTerms': [],
#                                                                      'phrases': [],
#                                                                      'terms': ['natur']},
#                                                  'stage': 'TEXT_MATCH',
#                                                  'textIndexVersion': 3},
#                                   'isCached': False,
#                                   'stage': 'PROJECTION_SIMPLE',
#                                   'transformBy': {'content': 1}}},
#  'queryShapeHash': '87A7B571EAC2302DEDE4C58FCC74DCC4CFEB7D06EF264FF9A947730F4F501E16',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %%
# Now let's use it in an aggregation pipeline.
# Perform the same search as a $match, then return the three matching posts with the highest followers_count.
# Return only the content and followers_count fields.

pipeline = [
    {"$match": {"$text": {"$search": "nature"}}},   # uses the text index
    {"$sort": {"followers_count": -1}},             # sort top followers
    {"$limit": 3},
    {"$project": {"_id": 0, "content": 1, "followers_count": 1}}
]

cursor = coll.aggregate(pipeline)

for doc in cursor:
    pprint(doc)
# Out:
# {'content': '<p>Large fallen tree covered in moss and lichen in <a '
#             'href="https://mstdn.ca/tags/Algonquin" class="mention hashtag" '
#             'rel="nofollow noopener" '
#             'target="_blank">#<span>Algonquin</span></a> Park. <a '
#             'href="https://mstdn.ca/tags/Ontario" class="mention hashtag" '
#             'rel="nofollow noopener" target="_blank">#<span>Ontario</span></a> '
#             '<a href="https://mstdn.ca/tags/Canada" class="mention hashtag" '
#             'rel="nofollow noopener" target="_blank">#<span>Canada</span></a> '
#             '</p><p><a href="https://mstdn.ca/tags/nature" class="mention '
#             'hashtag" rel="nofollow noopener" '
#             'target="_blank">#<span>nature</span></a> <a '
#             'href="https://mstdn.ca/tags/NaturePhotography" class="mention '
#             'hashtag" rel="nofollow noopener" '
#             'target="_blank">#<span>NaturePhotography</span></a></p>'}
# {'content': '<p>Reports on the homosexual behaviour of penguins in Antarctica '
#             'were hidden for over 100 years </p><p>“Animal Pride, a doc film '
#             'from CBC’s The Nature of Things, brings these findings into the '
#             'spotlight. </p><p>"We\'ve all heard the rhetoric that being queer '
#             'isn\'t natural," says naturalist Connel Bradwell in the film. '
#             '"This is nature\'s coming-out story."</p><p><a '
#             'href="https://www.cbc.ca/documentaries/the-nature-of-things/reports-on-the-homosexual-behaviour-of-penguins-in-antarctica-were-hidden-for-over-100-years-1.7541056" '
#             'rel="nofollow noopener" translate="no" target="_blank"><span '
#             'class="invisible">https://www.</span><span '
#             'class="ellipsis">cbc.ca/documentaries/the-natur</span><span '
#             'class="invisible">e-of-things/reports-on-the-homosexual-behaviour-of-penguins-in-antarctica-were-hidden-for-over-100-years-1.7541056</span></a></p>'}
# {'content': '<p>US PhD admissions shrink as fears over Trump’s cuts take '
#             'hold<br><a '
#             'href="https://www.nature.com/articles/d41586-025-03417-6?utm_source=flipboard&amp;utm_medium=activitypub" '
#             'rel="nofollow noopener" translate="no" target="_blank"><span '
#             'class="invisible">https://www.</span><span '
#             'class="ellipsis">nature.com/articles/d41586-025</span><span '
#             'class="invisible">-03417-6?utm_source=flipboard&amp;utm_medium=activitypub '
#             '</span></a></p><p>Posted into Latest science news <span '
#             'class="h-card" translate="no"><a '
#             'href="https://flipboard.com/@naturenewsteam/latest-science-news-d3hg9j0hz" '
#             'class="u-url mention" rel="nofollow noopener" '
#             'target="_blank">@<span>latest-science-news-NatureNewsteam</span></a></span></p>'}

# %%
# Now run that same pipeline with explain to see if it's using the text index.
# By the way, ... is it using the followers_count index? Why or why not?

plan = coll.database.command(
    "explain",
    {
        "aggregate": coll.name,
        "pipeline": pipeline,
        "cursor": {}
    },
    verbosity="executionStats"  # ✅ accepted here
)

pprint(plan)
# Out:
# {'command': {'$db': 'mastodon_test',
#              'aggregate': 'posts',
#              'cursor': {},
#              'pipeline': [{'$match': {'$text': {'$search': 'nature'}}},
#                           {'$sort': {'followers_count': -1}},
#                           {'$limit': 3},
#                           {'$project': {'_id': 0,
#                                         'content': 1,
#                                         'followers_count': 1}}]},
#  'executionStats': {'executionStages': {'advanced': 3,
#                                         'executionTimeMillisEstimate': 0,
#                                         'inputStage': {'advanced': 3,
#                                                        'executionTimeMillisEstimate': 0,
#                                                        'inputStage': {'advanced': 12,
#                                                                       'docsRejected': 0,
#                                                                       'executionTimeMillisEstimate': 0,
#                                                                       'indexName': 'content_text_index',
#                                                                       'indexPrefix': {},
#                                                                       'inputStage': {'advanced': 12,
#                                                                                      'alreadyHasObj': 0,
#                                                                                      'docsExamined': 12,
#                                                                                      'executionTimeMillisEstimate': 0,
#                                                                                      'inputStage': {'advanced': 12,
#                                                                                                     'direction': 'backward',
#                                                                                                     'dupsDropped': 0,
#                                                                                                     'dupsTested': 12,
#                                                                                                     'executionTimeMillisEstimate': 0,
#                                                                                                     'indexBounds': {},
#                                                                                                     'indexName': 'content_text_index',
#                                                                                                     'indexVersion': 2,
#                                                                                                     'isEOF': 1,
#                                                                                                     'isMultiKey': True,
#                                                                                                     'isPartial': False,
#                                                                                                     'isSparse': False,
#                                                                                                     'isUnique': False,
#                                                                                                     'keyPattern': {'_fts': 'text',
#                                                                                                                    '_ftsx': 1},
#                                                                                                     'keysExamined': 12,
#                                                                                                     'nReturned': 12,
#                                                                                                     'needTime': 0,
#                                                                                                     'needYield': 0,
#                                                                                                     'restoreState': 0,
#                                                                                                     'saveState': 0,
#                                                                                                     'seeks': 1,
#                                                                                                     'stage': 'IXSCAN',
#                                                                                                     'works': 13},
#                                                                                      'isEOF': 1,
#                                                                                      'nReturned': 12,
#                                                                                      'needTime': 0,
#                                                                                      'needYield': 0,
#                                                                                      'restoreState': 0,
#                                                                                      'saveState': 0,
#                                                                                      'stage': 'FETCH',
#                                                                                      'works': 13},
#                                                                       'isEOF': 1,
#                                                                       'nReturned': 12,
#                                                                       'needTime': 0,
#                                                                       'needYield': 0,
#                                                                       'parsedTextQuery': {'negatedPhrases': [],
#                                                                                           'negatedTerms': [],
#                                                                                           'phrases': [],
#                                                                                           'terms': ['natur']},
#                                                                       'restoreState': 0,
#                                                                       'saveState': 0,
#                                                                       'stage': 'TEXT_MATCH',
#                                                                       'textIndexVersion': 3,
#                                                                       'works': 13},
#                                                        'isEOF': 1,
#                                                        'limitAmount': 3,
#                                                        'memLimit': 104857600,
#                                                        'nReturned': 3,
#                                                        'needTime': 13,
#                                                        'needYield': 0,
#                                                        'restoreState': 0,
#                                                        'saveState': 0,
#                                                        'sortPattern': {'followers_count': -1},
#                                                        'spilledDataStorageSize': 0,
#                                                        'spills': 0,
#                                                        'stage': 'SORT',
#                                                        'totalDataSizeSorted': 11284,
#                                                        'type': 'simple',
#                                                        'usedDisk': False,
#                                                        'works': 17},
#                                         'isCached': False,
#                                         'isEOF': 1,
#                                         'nReturned': 3,
#                                         'needTime': 13,
#                                         'needYield': 0,
#                                         'restoreState': 0,
#                                         'saveState': 0,
#                                         'stage': 'PROJECTION_SIMPLE',
#                                         'transformBy': {'_id': False,
#                                                         'content': True,
#                                                         'followers_count': True},
#                                         'works': 17},
#                     'executionSuccess': True,
#                     'executionTimeMillis': 0,
#                     'nReturned': 3,
#                     'totalDocsExamined': 12,
#                     'totalKeysExamined': 12},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'queryPlanner': {'indexFilterSet': False,
#                   'maxIndexedAndSolutionsReached': False,
#                   'maxIndexedOrSolutionsReached': False,
#                   'maxScansToExplodeReached': False,
#                   'namespace': 'mastodon_test.posts',
#                   'optimizationTimeMillis': 0,
#                   'optimizedPipeline': True,
#                   'parsedQuery': {'$text': {'$caseSensitive': False,
#                                             '$diacriticSensitive': False,
#                                             '$language': 'english',
#                                             '$search': 'nature'}},
#                   'planCacheKey': '1A0F6A1F',
#                   'planCacheShapeHash': '46ED0005',
#                   'prunedSimilarIndexes': False,
#                   'queryHash': '46ED0005',
#                   'rejectedPlans': [],
#                   'winningPlan': {'inputStage': {'inputStage': {'indexName': 'content_text_index',
#                                                                 'indexPrefix': {},
#                                                                 'inputStage': {'inputStage': {'direction': 'backward',
#                                                                                               'indexBounds': {},
#                                                                                               'indexName': 'content_text_index',
#                                                                                               'indexVersion': 2,
#                                                                                               'isMultiKey': True,
#                                                                                               'isPartial': False,
#                                                                                               'isSparse': False,
#                                                                                               'isUnique': False,
#                                                                                               'keyPattern': {'_fts': 'text',
#                                                                                                              '_ftsx': 1},
#                                                                                               'stage': 'IXSCAN'},
#                                                                                'stage': 'FETCH'},
#                                                                 'parsedTextQuery': {'negatedPhrases': [],
#                                                                                     'negatedTerms': [],
#                                                                                     'phrases': [],
#                                                                                     'terms': ['natur']},
#                                                                 'stage': 'TEXT_MATCH',
#                                                                 'textIndexVersion': 3},
#                                                  'limitAmount': 3,
#                                                  'memLimit': 104857600,
#                                                  'sortPattern': {'followers_count': -1},
#                                                  'stage': 'SORT',
#                                                  'type': 'simple'},
#                                   'isCached': False,
#                                   'stage': 'PROJECTION_SIMPLE',
#                                   'transformBy': {'_id': False,
#                                                   'content': True,
#                                                   'followers_count': True}}},
#  'queryShapeHash': '6048EE22EC8531CDE0DF0B49C488A23673B4233B5B491517F5791EC76F6E042C',
#  'serverInfo': {'gitVersion': '7f52660c14217ed2c8d3240f823a2291a4fe6abd',
#                 'host': 'Kriss-MacBook-Pro.local',
#                 'port': 27017,
#                 'version': '8.0.8'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryFrameworkControl': 'trySbeRestricted',
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0}}

# %% [markdown]
# # Save this file WITH ALL OUTPUT SHOWING and submit to Canvas
